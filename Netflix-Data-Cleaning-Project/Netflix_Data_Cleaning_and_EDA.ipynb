# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Reading and checking the dataset**

# %%
df=pd.read_csv("netflix.csv")
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 12 columns]

# %% [markdown]
# **To see all columns**

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# **Renaming the listed in column to genres**

# %%
df.rename(columns={'listed_in':'genre'},inplace=True)
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'genre', 'description'],
#       dtype='object')

# %% [markdown]
# **Dropping the show_id column as it may be of no use in the analysis**

# %%
df.drop('show_id',axis=1,inplace=True)
df.columns
# Out:
# Index(['type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'genre', 'description'],
#       dtype='object')

# %% [markdown]
# **Checking for duplicates**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Checking the missing values**

# %%
df.isna().sum()   # another way df.isnull().sum()
# Out:
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# genre              0
# description        0
# dtype: int64

# %% [markdown]
# **Dropping the rows which have null values in date_added column as there are only 10 values**

# %%
df.dropna(subset=['date_added'],inplace=True)
df['date_added'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Dropping the rows which have null values in rating column as there are only 4 values**

# %%
df.dropna(subset=['rating'],inplace=True)
df['rating'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Dropping the rows which have null values in duration column as there are only 3 values**

# %%
df=df.dropna(subset=['duration'])
df['duration'].isna().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# type               0
# title              0
# director        2621
# cast             825
# country          829
# date_added         0
# release_year       0
# rating             0
# duration           0
# genre              0
# description        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8790 entries, 0 to 8806
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8790 non-null   object
#  1   title         8790 non-null   object
#  2   director      6169 non-null   object
#  3   cast          7965 non-null   object
#  4   country       7961 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   genre         8790 non-null   object
#  10  description   8790 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 824.1+ KB

# %% [markdown]
# ** When there is some mismatch in our date format then that values is replaced by null**

# %%
df['date_added']=pd.to_datetime(df['date_added'],errors='coerce')
df['date_added'].isna().sum()
# Out:
# /var/folders/ms/5qd06gb52fb11qfl6dns7nwc0000gn/T/ipykernel_58897/2359665471.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date_added']=pd.to_datetime(df['date_added'],errors='coerce')
# np.int64(88)

# %%
df.dropna(subset=['date_added'],inplace=True)
df['date_added'].isna().sum()
# Out:
# /var/folders/ms/5qd06gb52fb11qfl6dns7nwc0000gn/T/ipykernel_58897/817333644.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['date_added'],inplace=True)
# np.int64(0)

# %% [markdown]
# **Adding day, month, year, month_name,day_name as seprated columns**

# %%
df['day']=df['date_added'].dt.day
df['month']=df['date_added'].dt.month
df['year']=df['date_added'].dt.year
df['month_name']=df['date_added'].dt.month_name()
df['weekday']=df['date_added'].dt.day_name()
df.head()
# Out:
# /var/folders/ms/5qd06gb52fb11qfl6dns7nwc0000gn/T/ipykernel_58897/3694861535.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day']=df['date_added'].dt.day
# /var/folders/ms/5qd06gb52fb11qfl6dns7nwc0000gn/T/ipykernel_58897/3694861535.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month']=df['date_added'].dt.month
# /var/folders/ms/5qd06gb52fb11qfl6dns7nwc0000gn/T/ipykernel_58897/3694861535.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year']=df['date_added'].dt.year
# /var/folders/ms/5qd06gb52fb11qfl6dns7nwc0000gn/T/ipykernel_58897/3694861535.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month_name']=df['date_added'].dt.month_name()
# /var/folders/ms/5qd06gb52fb11qfl6dns7nwc0000gn/T/ipykernel_58897/3694861535.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['weekday']=df['date_added'].dt.day_name()
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# 3 2021-09-24          2021  TV-MA   1 Season
# 4 2021-09-24          2021  TV-MA  2 Seasons
#
#                                                genre  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description  day  month  year  \
# 0  As her father nears the end of his life, filmm...   25      9  2021
# 1  After crossing paths at a party, a Cape Town t...   24      9  2021
# 2  To protect his family from a powerful drug lor...   24      9  2021
# 3  Feuds, flirtations and toilet talk go down amo...   24      9  2021
# 4  In a city of coaching centers known to train I...   24      9  2021
#
#   month_name   weekday
# 0  September  Saturday
# 1  September    Friday
# 2  September    Friday
# 3  September    Friday
# 4  September    Friday

# %%
df['duration'].unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
#        '140 min', '78 min', '7 Seasons', '64 min', '59 min', '139 min',
#        '69 min', '148 min', '189 min', '141 min', '130 min', '138 min',
#        '81 min', '132 min', '10 Seasons', '123 min', '65 min', '68 min',
#        '66 min', '62 min', '74 min', '131 min', '39 min', '46 min',
#        '38 min', '8 Seasons', '17 Seasons', '126 min', '155 min',
#        '159 min', '137 min', '12 min', '273 min', '36 min', '34 min',
#        '77 min', '60 min', '49 min', '58 min', '72 min', '204 min',
#        '212 min', '25 min', '73 min', '29 min', '47 min', '32 min',
#        '35 min', '71 min', '149 min', '33 min', '15 min', '54 min',
#        '224 min', '162 min', '37 min', '75 min', '79 min', '55 min',
#        '158 min', '164 min', '173 min', '181 min', '185 min', '21 min',
#        '24 min', '51 min', '151 min', '42 min', '22 min', '134 min',
#        '177 min', '13 Seasons', '52 min', '14 min', '53 min', '8 min',
#        '57 min', '28 min', '50 min', '9 min', '26 min', '45 min',
#        '171 min', '27 min', '44 min', '146 min', '20 min', '157 min',
#        '17 min', '203 min', '41 min', '30 min', '194 min', '15 Seasons',
#        '233 min', '237 min', '230 min', '195 min', '253 min', '152 min',
#        '190 min', '160 min', '208 min', '180 min', '144 min', '5 min',
#        '174 min', '170 min', '192 min', '209 min', '187 min', '172 min',
#        '16 min', '186 min', '11 min', '193 min', '176 min', '56 min',
#        '169 min', '40 min', '10 min', '3 min', '168 min', '312 min',
#        '153 min', '214 min', '31 min', '163 min', '19 min', '12 Seasons',
#        '179 min', '43 min', '200 min', '196 min', '167 min', '178 min',
#        '228 min', '18 min', '205 min', '201 min', '191 min'], dtype=object)

# %%
s1='90 min'
int(s1.split()[0])
# Out:
# 90

# %%
s1='13 Seasons'
int(s1.split()[0])
# Out:
# 13

# %%
df['duration']=df['duration'].apply(lambda x:int(x.split()[0]))
df['duration'].unique()
# Out:
# /var/folders/ms/5qd06gb52fb11qfl6dns7nwc0000gn/T/ipykernel_58897/1106310186.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['duration']=df['duration'].apply(lambda x:int(x.split()[0]))
# array([ 90,   2,   1,  91, 125,   9, 104, 127,   4,  67,  94,   5, 161,
#         61, 166, 147, 103,  97, 106, 111,   3, 110, 105,  96, 124, 116,
#         98,  23, 115, 122,  99,  88, 100,   6, 102,  93,  95,  85,  83,
#        113,  13, 182,  48, 145,  87,  92,  80, 117, 128, 119, 143, 114,
#        118, 108,  63, 121, 142, 154, 120,  82, 109, 101,  86, 229,  76,
#         89, 156, 112, 107, 129, 135, 136, 165, 150, 133,  70,  84, 140,
#         78,   7,  64,  59, 139,  69, 148, 189, 141, 130, 138,  81, 132,
#         10, 123,  65,  68,  66,  62,  74, 131,  39,  46,  38,   8,  17,
#        126, 155, 159, 137,  12, 273,  36,  34,  77,  60,  49,  58,  72,
#        204, 212,  25,  73,  29,  47,  32,  35,  71, 149,  33,  15,  54,
#        224, 162,  37,  75,  79,  55, 158, 164, 173, 181, 185,  21,  24,
#         51, 151,  42,  22, 134, 177,  52,  14,  53,  57,  28,  50,  26,
#         45, 171,  27,  44, 146,  20, 157, 203,  41,  30, 194, 233, 237,
#        230, 195, 253, 152, 190, 160, 208, 180, 144, 174, 170, 192, 209,
#        187, 172,  16, 186,  11, 193, 176,  56, 169,  40, 168, 312, 153,
#        214,  31, 163,  19, 179,  43, 200, 196, 167, 178, 228,  18, 205,
#        201, 191])

# %% [markdown]
# **Checking for unique values of rating and categorising them for better understanding**

# %%
df['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
df['rating']=df['rating'].replace(['TV-Y','TV-Y7',"G",'TV-G','PG','TV-PG','TV-Y7-FV'],'kids')
df['rating']=df['rating'].replace(['PG-13','TV-14'],'teens')
df['rating']=df['rating'].replace(['R','TV-MA','NC', 'NC-17'],'adults')
df['rating']=df['rating'].replace(['NR','UR'],np.nan)
df
# Out:
# /var/folders/ms/5qd06gb52fb11qfl6dns7nwc0000gn/T/ipykernel_58897/4171577002.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rating']=df['rating'].replace(['TV-Y','TV-Y7',"G",'TV-G','PG','TV-PG','TV-Y7-FV'],'kids')
# /var/folders/ms/5qd06gb52fb11qfl6dns7nwc0000gn/T/ipykernel_58897/4171577002.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rating']=df['rating'].replace(['PG-13','TV-14'],'teens')
# /var/folders/ms/5qd06gb52fb11qfl6dns7nwc0000gn/T/ipykernel_58897/4171577002.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rating']=df['rating'].replace(['R','TV-MA','NC', 'NC-17'],'adults')
# /var/folders/ms/5qd06gb52fb11qfl6dns7nwc0000gn/T/ipykernel_58897/4171577002.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rating']=df['rating'].replace(['NR','UR'],np.nan)
#          type                  title         director  \
# 0       Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1     TV Show          Blood & Water              NaN
# 2     TV Show              Ganglands  Julien Leclercq
# 3     TV Show  Jailbirds New Orleans              NaN
# 4     TV Show           Kota Factory              NaN
# ...       ...                    ...              ...
# 8802    Movie                 Zodiac    David Fincher
# 8803  TV Show            Zombie Dumb              NaN
# 8804    Movie             Zombieland  Ruben Fleischer
# 8805    Movie                   Zoom     Peter Hewitt
# 8806    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#      date_added  release_year  rating  duration  \
# 0    2021-09-25          2020   teens        90
# 1    2021-09-24          2021  adults         2
# 2    2021-09-24          2021  adults         1
# 3    2021-09-24          2021  adults         1
# 4    2021-09-24          2021  adults         2
# ...         ...           ...     ...       ...
# 8802 2019-11-20          2007  adults       158
# 8803 2019-07-01          2018    kids         2
# 8804 2019-11-01          2009  adults        88
# 8805 2020-01-11          2006    kids        88
# 8806 2019-03-02          2015   teens       111
#
#                                                   genre  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description  day  month  year  \
# 0     As her father nears the end of his life, filmm...   25      9  2021
# 1     After crossing paths at a party, a Cape Town t...   24      9  2021
# 2     To protect his family from a powerful drug lor...   24      9  2021
# 3     Feuds, flirtations and toilet talk go down amo...   24      9  2021
# 4     In a city of coaching centers known to train I...   24      9  2021
# ...                                                 ...  ...    ...   ...
# 8802  A political cartoonist, a crime reporter and a...   20     11  2019
# 8803  While living alone in a spooky town, a young g...    1      7  2019
# 8804  Looking to survive in a world taken over by zo...    1     11  2019
# 8805  Dragged from civilian life, a former superhero...   11      1  2020
# 8806  A scrappy but poor boy worms his way into a ty...    2      3  2019
#
#      month_name    weekday
# 0     September   Saturday
# 1     September     Friday
# 2     September     Friday
# 3     September     Friday
# 4     September     Friday
# ...         ...        ...
# 8802   November  Wednesday
# 8803       July     Monday
# 8804   November     Friday
# 8805    January   Saturday
# 8806      March   Saturday
#
# [8702 rows x 16 columns]

# %%
df['rating'].unique()
# Out:
# array(['teens', 'adults', 'kids', nan], dtype=object)

# %%
df['rating'].isnull().sum()
# Out:
# np.int64(81)

# %%
df.dropna(subset=['rating'],inplace=True)
# Out:
# /var/folders/ms/5qd06gb52fb11qfl6dns7nwc0000gn/T/ipykernel_58897/1044244190.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['rating'],inplace=True)

# %%
df['rating'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# type               0
# title              0
# director        2535
# cast             800
# country          826
# date_added         0
# release_year       0
# rating             0
# duration           0
# genre              0
# description        0
# day                0
# month              0
# year               0
# month_name         0
# weekday            0
# dtype: int64

# %% [markdown]
# **Now we still have about 48% missing data .So, we will check in which rows the director, country and cast all three are null, if all these 3 are null then there is no use of that row**

# %%
df[(df['director'].isna())&(df['country'].isna())&(df['cast'].isna())]
# Out:
#          type                                      title director cast  \
# 3     TV Show                      Jailbirds New Orleans      NaN  NaN
# 10    TV Show        Vendetta: Truth, Lies and The Mafia      NaN  NaN
# 14    TV Show            Crime Stories: India Detectives      NaN  NaN
# 74    TV Show  The World's Most Amazing Vacation Rentals      NaN  NaN
# 123   TV Show                                  Luv Kushh      NaN  NaN
# ...       ...                                        ...      ...  ...
# 7812  TV Show                           Queens of Comedy      NaN  NaN
# 8109  TV Show                                 Strongland      NaN  NaN
# 8199  TV Show                               The Bachelor      NaN  NaN
# 8609  TV Show                                     Towies      NaN  NaN
# 8803  TV Show                                Zombie Dumb      NaN  NaN
#
#      country date_added  release_year  rating  duration  \
# 3        NaN 2021-09-24          2021  adults         1
# 10       NaN 2021-09-24          2021  adults         1
# 14       NaN 2021-09-22          2021  adults         1
# 74       NaN 2021-09-14          2021    kids         2
# 123      NaN 2021-09-02          2012    kids         1
# ...      ...        ...           ...     ...       ...
# 7812     NaN 2018-05-01          2017  adults         1
# 8109     NaN 2019-01-18          2018    kids         1
# 8199     NaN 2019-12-01          2009   teens         1
# 8609     NaN 2017-12-27          2016  adults         1
# 8803     NaN 2019-07-01          2018    kids         2
#
#                                                   genre  \
# 3                                Docuseries, Reality TV
# 10    Crime TV Shows, Docuseries, International TV S...
# 14         British TV Shows, Crime TV Shows, Docuseries
# 74                                           Reality TV
# 123                                            Kids' TV
# ...                                                 ...
# 7812  International TV Shows, Stand-Up Comedy & Talk...
# 8109                 Docuseries, International TV Shows
# 8199                      Reality TV, Romantic TV Shows
# 8609                 International TV Shows, Reality TV
# 8803             Kids' TV, Korean TV Shows, TV Comedies
#
#                                             description  day  month  year  \
# 3     Feuds, flirtations and toilet talk go down amo...   24      9  2021
# 10    Sicily boasts a bold "Anti-Mafia" coalition. B...   24      9  2021
# 14    Cameras following Bengaluru police on the job ...   22      9  2021
# 74    With an eye for every budget, three travelers ...   14      9  2021
# 123   Based on the last book of the epic Ramayana, t...    2      9  2021
# ...                                                 ...  ...    ...   ...
# 7812  Eight women perform in front of celebrity judg...    1      5  2018
# 8109  From Spain's countryside to Scotland's stony t...   18      1  2019
# 8199  A single man searches for his soulmate through...    1     12  2019
# 8609  Australia's toughest tow truck operators work ...   27     12  2017
# 8803  While living alone in a spooky town, a young g...    1      7  2019
#
#      month_name    weekday
# 3     September     Friday
# 10    September     Friday
# 14    September  Wednesday
# 74    September    Tuesday
# 123   September   Thursday
# ...         ...        ...
# 7812        May    Tuesday
# 8109    January     Friday
# 8199   December     Sunday
# 8609   December  Wednesday
# 8803       July     Monday
#
# [96 rows x 16 columns]

# %%
df[(df['director'].isna())&(df['country'].isna())&(df['cast'].isna())].shape[0]
# Out:
# 96

# %% [markdown]
# **We found out that total 96 such rows are there which dont have director,country and cast as null,so deleting those rows**

# %%
df.shape
# Out:
# (8621, 16)

# %%
df.dropna(subset=['director','country','cast'],how='all',inplace=True) #how=all stands for deleting only those rows which has null in all three columns director,country,cast
df.shape
# Out:
# /var/folders/ms/5qd06gb52fb11qfl6dns7nwc0000gn/T/ipykernel_58897/1191777066.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['director','country','cast'],how='all',inplace=True) #how=all stands for deleting only those rows which has null in all three columns director,country,cast
# (8525, 16)

# %%
df.isna().sum()
# Out:
# type               0
# title              0
# director        2439
# cast             704
# country          730
# date_added         0
# release_year       0
# rating             0
# duration           0
# genre              0
# description        0
# day                0
# month              0
# year               0
# month_name         0
# weekday            0
# dtype: int64

# %%
df['cast'][2].split(', ')
# Out:
# ['Sami Bouajila',
#  'Tracy Gotoas',
#  'Samuel Jouy',
#  'Nabiha Akkari',
#  'Sofia Lesaffre',
#  'Salim Kechiouche',
#  'Noureddine Farihi',
#  'Geert Van Rampelberg',
#  'Bakary Diombera']

# %%
df_cast=pd.DataFrame(df['cast'].apply(lambda x: str(x).split(', ')).tolist(),index=df['title'])
df_cast
# Out:
#                                    0                1                  2   \
# title
# Dick Johnson Is Dead              nan             None               None
# Blood & Water              Ama Qamata      Khosi Ngema      Gail Mabalane
# Ganglands               Sami Bouajila     Tracy Gotoas        Samuel Jouy
# Kota Factory               Mayur More   Jitendra Kumar         Ranjan Raj
# Midnight Mass             Kate Siegel     Zach Gilford   Hamish Linklater
# ...                               ...              ...                ...
# Zinzana                   Ali Suliman      Saleh Bakri               Yasa
# Zodiac                   Mark Ruffalo  Jake Gyllenhaal  Robert Downey Jr.
# Zombieland            Jesse Eisenberg  Woody Harrelson         Emma Stone
# Zoom                        Tim Allen    Courteney Cox        Chevy Chase
# Zubaan                  Vicky Kaushal  Sarah-Jane Dias    Raaghav Chanana
#
#                                     3                 4                 5   \
# title
# Dick Johnson Is Dead              None              None              None
# Blood & Water           Thabang Molaba  Dillon Windvogel   Natasha Thahane
# Ganglands                Nabiha Akkari    Sofia Lesaffre  Salim Kechiouche
# Kota Factory                 Alam Khan     Ahsaas Channa    Revathi Pillai
# Midnight Mass             Henry Thomas    Kristin Lehman   Samantha Sloyan
# ...                                ...               ...               ...
# Zinzana                   Ali Al-Jabri   Mansoor Alfeeli               Ahd
# Zodiac                 Anthony Edwards         Brian Cox      Elias Koteas
# Zombieland             Abigail Breslin       Amber Heard       Bill Murray
# Zoom                         Kate Mara       Ryan Newman   Michael Cassidy
# Zubaan                Manish Chaudhary      Meghna Malik     Malkeet Rauni
#
#                                      6                      7   \
# title
# Dick Johnson Is Dead               None                   None
# Blood & Water               Arno Greeff      Xolile Tshabalala
# Ganglands             Noureddine Farihi   Geert Van Rampelberg
# Kota Factory                 Urvi Singh             Arun Kumar
# Midnight Mass               Igby Rigney            Rahul Kohli
# ...                                 ...                    ...
# Zinzana                            None                   None
# Zodiac                      Donal Logue     John Carroll Lynch
# Zombieland                   Derek Graf                   None
# Zoom                    Spencer Breslin               Rip Torn
# Zubaan                   Anita Shabdish  Chittaranjan Tripathy
#
#                                    8               9   ...    40    41    42  \
# title                                                  ...
# Dick Johnson Is Dead             None            None  ...  None  None  None
# Blood & Water         Getmore Sithole  Cindy Mahlangu  ...  None  None  None
# Ganglands             Bakary Diombera            None  ...  None  None  None
# Kota Factory                     None            None  ...  None  None  None
# Midnight Mass          Annarah Cymone   Annabeth Gish  ...  None  None  None
# ...                               ...             ...  ...   ...   ...   ...
# Zinzana                          None            None  ...  None  None  None
# Zodiac                Dermot Mulroney   Chloë Sevigny  ...  None  None  None
# Zombieland                       None            None  ...  None  None  None
# Zoom                     Kevin Zegers            None  ...  None  None  None
# Zubaan                           None            None  ...  None  None  None
#
#                         43    44    45    46    47    48    49
# title
# Dick Johnson Is Dead  None  None  None  None  None  None  None
# Blood & Water         None  None  None  None  None  None  None
# Ganglands             None  None  None  None  None  None  None
# Kota Factory          None  None  None  None  None  None  None
# Midnight Mass         None  None  None  None  None  None  None
# ...                    ...   ...   ...   ...   ...   ...   ...
# Zinzana               None  None  None  None  None  None  None
# Zodiac                None  None  None  None  None  None  None
# Zombieland            None  None  None  None  None  None  None
# Zoom                  None  None  None  None  None  None  None
# Zubaan                None  None  None  None  None  None  None
#
# [8525 rows x 50 columns]

# %%
df_cast=df_cast.stack()
df_cast
# Out:
# title
# Dick Johnson Is Dead  0                      nan
# Blood & Water         0               Ama Qamata
#                       1              Khosi Ngema
#                       2            Gail Mabalane
#                       3           Thabang Molaba
#                                    ...
# Zubaan                3         Manish Chaudhary
#                       4             Meghna Malik
#                       5            Malkeet Rauni
#                       6           Anita Shabdish
#                       7    Chittaranjan Tripathy
# Length: 63644, dtype: object

# %%
df_cast=pd.DataFrame(df_cast)
df_cast
# Out:
#                                             0
# title
# Dick Johnson Is Dead 0                    nan
# Blood & Water        0             Ama Qamata
#                      1            Khosi Ngema
#                      2          Gail Mabalane
#                      3         Thabang Molaba
# ...                                       ...
# Zubaan               3       Manish Chaudhary
#                      4           Meghna Malik
#                      5          Malkeet Rauni
#                      6         Anita Shabdish
#                      7  Chittaranjan Tripathy
#
# [63644 rows x 1 columns]

# %%
df_cast.reset_index(inplace=True) # Title convert back to column
df_cast
# Out:
#                       title  level_1                      0
# 0      Dick Johnson Is Dead        0                    nan
# 1             Blood & Water        0             Ama Qamata
# 2             Blood & Water        1            Khosi Ngema
# 3             Blood & Water        2          Gail Mabalane
# 4             Blood & Water        3         Thabang Molaba
# ...                     ...      ...                    ...
# 63639                Zubaan        3       Manish Chaudhary
# 63640                Zubaan        4           Meghna Malik
# 63641                Zubaan        5          Malkeet Rauni
# 63642                Zubaan        6         Anita Shabdish
# 63643                Zubaan        7  Chittaranjan Tripathy
#
# [63644 rows x 3 columns]

# %%
df_cast=df_cast[['title',0]]
df_cast
# Out:
#                       title                      0
# 0      Dick Johnson Is Dead                    nan
# 1             Blood & Water             Ama Qamata
# 2             Blood & Water            Khosi Ngema
# 3             Blood & Water          Gail Mabalane
# 4             Blood & Water         Thabang Molaba
# ...                     ...                    ...
# 63639                Zubaan       Manish Chaudhary
# 63640                Zubaan           Meghna Malik
# 63641                Zubaan          Malkeet Rauni
# 63642                Zubaan         Anita Shabdish
# 63643                Zubaan  Chittaranjan Tripathy
#
# [63644 rows x 2 columns]

# %%
df_cast.columns=['title','cast']
df_cast
# Out:
#                       title                   cast
# 0      Dick Johnson Is Dead                    nan
# 1             Blood & Water             Ama Qamata
# 2             Blood & Water            Khosi Ngema
# 3             Blood & Water          Gail Mabalane
# 4             Blood & Water         Thabang Molaba
# ...                     ...                    ...
# 63639                Zubaan       Manish Chaudhary
# 63640                Zubaan           Meghna Malik
# 63641                Zubaan          Malkeet Rauni
# 63642                Zubaan         Anita Shabdish
# 63643                Zubaan  Chittaranjan Tripathy
#
# [63644 rows x 2 columns]

# %%
df_cast.replace('nan',np.nan,inplace=True)
df_cast.isna().sum()
# Out:
# /var/folders/ms/5qd06gb52fb11qfl6dns7nwc0000gn/T/ipykernel_58897/154984155.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cast.replace('nan',np.nan,inplace=True)
# title      0
# cast     704
# dtype: int64

# %%
df_genre=pd.DataFrame(df['genre'].apply(lambda x: str(x).split(', ')).tolist(),index=df['title'])
df_genre=df_genre.stack()
df_genre=pd.DataFrame(df_genre)
df_genre.reset_index(inplace=True)
df_genre=df_genre[['title',0]]
df_genre.columns=['title','genre']
df_genre.replace('nan',np.nan,inplace=True)
df_genre.isna().sum()
# Out:
# title    0
# genre    0
# dtype: int64

# %%
df_director=pd.DataFrame(df['director'].apply(lambda x: str(x).split(', ')).tolist(),index=df['title'])
df_director=df_director.stack()
df_director=pd.DataFrame(df_director)
df_director.reset_index(inplace=True)
df_director=df_director[['title',0]]
df_director.columns=['title','director']
df_director.replace('nan',np.nan,inplace=True)
df_director.isna().sum()
# Out:
# title          0
# director    2439
# dtype: int64

# %%
df_country=pd.DataFrame(df['country'].apply(lambda x: str(x).split(', ')).tolist(),index=df['title'])
df_country=df_country.stack()
df_country=pd.DataFrame(df_country)
df_country.reset_index(inplace=True)
df_country=df_country[['title',0]]
df_country.columns=['title','country']
df_country.replace('nan',np.nan,inplace=True)
df_country.isna().sum()
# Out:
# title        0
# country    730
# dtype: int64

# %%
df12=df_cast.merge(df_genre,on='title')
df12
# Out:
#                        title                   cast                   genre
# 0       Dick Johnson Is Dead                    NaN           Documentaries
# 1              Blood & Water             Ama Qamata  International TV Shows
# 2              Blood & Water             Ama Qamata               TV Dramas
# 3              Blood & Water             Ama Qamata            TV Mysteries
# 4              Blood & Water            Khosi Ngema  International TV Shows
# ...                      ...                    ...                     ...
# 146662                Zubaan         Anita Shabdish    International Movies
# 146663                Zubaan         Anita Shabdish        Music & Musicals
# 146664                Zubaan  Chittaranjan Tripathy                  Dramas
# 146665                Zubaan  Chittaranjan Tripathy    International Movies
# 146666                Zubaan  Chittaranjan Tripathy        Music & Musicals
#
# [146667 rows x 3 columns]

# %%
df123=df_director.merge(df12,on='title')
df123
# Out:
#                        title         director                   cast  \
# 0       Dick Johnson Is Dead  Kirsten Johnson                    NaN
# 1              Blood & Water              NaN             Ama Qamata
# 2              Blood & Water              NaN             Ama Qamata
# 3              Blood & Water              NaN             Ama Qamata
# 4              Blood & Water              NaN            Khosi Ngema
# ...                      ...              ...                    ...
# 158309                Zubaan      Mozez Singh         Anita Shabdish
# 158310                Zubaan      Mozez Singh         Anita Shabdish
# 158311                Zubaan      Mozez Singh  Chittaranjan Tripathy
# 158312                Zubaan      Mozez Singh  Chittaranjan Tripathy
# 158313                Zubaan      Mozez Singh  Chittaranjan Tripathy
#
#                          genre
# 0                Documentaries
# 1       International TV Shows
# 2                    TV Dramas
# 3                 TV Mysteries
# 4       International TV Shows
# ...                        ...
# 158309    International Movies
# 158310        Music & Musicals
# 158311                  Dramas
# 158312    International Movies
# 158313        Music & Musicals
#
# [158314 rows x 4 columns]

# %%
df1234=df_country.merge(df123,on='title')
df1234
# Out:
#                        title        country         director  \
# 0       Dick Johnson Is Dead  United States  Kirsten Johnson
# 1              Blood & Water   South Africa              NaN
# 2              Blood & Water   South Africa              NaN
# 3              Blood & Water   South Africa              NaN
# 4              Blood & Water   South Africa              NaN
# ...                      ...            ...              ...
# 198399                Zubaan          India      Mozez Singh
# 198400                Zubaan          India      Mozez Singh
# 198401                Zubaan          India      Mozez Singh
# 198402                Zubaan          India      Mozez Singh
# 198403                Zubaan          India      Mozez Singh
#
#                          cast                   genre
# 0                         NaN           Documentaries
# 1                  Ama Qamata  International TV Shows
# 2                  Ama Qamata               TV Dramas
# 3                  Ama Qamata            TV Mysteries
# 4                 Khosi Ngema  International TV Shows
# ...                       ...                     ...
# 198399         Anita Shabdish    International Movies
# 198400         Anita Shabdish        Music & Musicals
# 198401  Chittaranjan Tripathy                  Dramas
# 198402  Chittaranjan Tripathy    International Movies
# 198403  Chittaranjan Tripathy        Music & Musicals
#
# [198404 rows x 5 columns]

# %%
df_new=df1234.merge(df,on='title')
df_new
# Out:
#                        title      country_x       director_x  \
# 0       Dick Johnson Is Dead  United States  Kirsten Johnson
# 1              Blood & Water   South Africa              NaN
# 2              Blood & Water   South Africa              NaN
# 3              Blood & Water   South Africa              NaN
# 4              Blood & Water   South Africa              NaN
# ...                      ...            ...              ...
# 198399                Zubaan          India      Mozez Singh
# 198400                Zubaan          India      Mozez Singh
# 198401                Zubaan          India      Mozez Singh
# 198402                Zubaan          India      Mozez Singh
# 198403                Zubaan          India      Mozez Singh
#
#                        cast_x                 genre_x     type  \
# 0                         NaN           Documentaries    Movie
# 1                  Ama Qamata  International TV Shows  TV Show
# 2                  Ama Qamata               TV Dramas  TV Show
# 3                  Ama Qamata            TV Mysteries  TV Show
# 4                 Khosi Ngema  International TV Shows  TV Show
# ...                       ...                     ...      ...
# 198399         Anita Shabdish    International Movies    Movie
# 198400         Anita Shabdish        Music & Musicals    Movie
# 198401  Chittaranjan Tripathy                  Dramas    Movie
# 198402  Chittaranjan Tripathy    International Movies    Movie
# 198403  Chittaranjan Tripathy        Music & Musicals    Movie
#
#              director_y                                             cast_y  \
# 0       Kirsten Johnson                                                NaN
# 1                   NaN  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2                   NaN  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 3                   NaN  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 4                   NaN  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...                 ...                                                ...
# 198399      Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 198400      Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 198401      Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 198402      Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 198403      Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#             country_y date_added  release_year  rating  duration  \
# 0       United States 2021-09-25          2020   teens        90
# 1        South Africa 2021-09-24          2021  adults         2
# 2        South Africa 2021-09-24          2021  adults         2
# 3        South Africa 2021-09-24          2021  adults         2
# 4        South Africa 2021-09-24          2021  adults         2
# ...               ...        ...           ...     ...       ...
# 198399          India 2019-03-02          2015   teens       111
# 198400          India 2019-03-02          2015   teens       111
# 198401          India 2019-03-02          2015   teens       111
# 198402          India 2019-03-02          2015   teens       111
# 198403          India 2019-03-02          2015   teens       111
#
#                                                 genre_y  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2       International TV Shows, TV Dramas, TV Mysteries
# 3       International TV Shows, TV Dramas, TV Mysteries
# 4       International TV Shows, TV Dramas, TV Mysteries
# ...                                                 ...
# 198399   Dramas, International Movies, Music & Musicals
# 198400   Dramas, International Movies, Music & Musicals
# 198401   Dramas, International Movies, Music & Musicals
# 198402   Dramas, International Movies, Music & Musicals
# 198403   Dramas, International Movies, Music & Musicals
#
#                                               description  day  month  year  \
# 0       As her father nears the end of his life, filmm...   25      9  2021
# 1       After crossing paths at a party, a Cape Town t...   24      9  2021
# 2       After crossing paths at a party, a Cape Town t...   24      9  2021
# 3       After crossing paths at a party, a Cape Town t...   24      9  2021
# 4       After crossing paths at a party, a Cape Town t...   24      9  2021
# ...                                                   ...  ...    ...   ...
# 198399  A scrappy but poor boy worms his way into a ty...    2      3  2019
# 198400  A scrappy but poor boy worms his way into a ty...    2      3  2019
# 198401  A scrappy but poor boy worms his way into a ty...    2      3  2019
# 198402  A scrappy but poor boy worms his way into a ty...    2      3  2019
# 198403  A scrappy but poor boy worms his way into a ty...    2      3  2019
#
#        month_name   weekday
# 0       September  Saturday
# 1       September    Friday
# 2       September    Friday
# 3       September    Friday
# 4       September    Friday
# ...           ...       ...
# 198399      March  Saturday
# 198400      March  Saturday
# 198401      March  Saturday
# 198402      March  Saturday
# 198403      March  Saturday
#
# [198404 rows x 20 columns]

# %%
df_new.drop(columns=['country_y','director_y','cast_y','genre_y'],inplace=True)
df_new
# Out:
#                        title      country_x       director_x  \
# 0       Dick Johnson Is Dead  United States  Kirsten Johnson
# 1              Blood & Water   South Africa              NaN
# 2              Blood & Water   South Africa              NaN
# 3              Blood & Water   South Africa              NaN
# 4              Blood & Water   South Africa              NaN
# ...                      ...            ...              ...
# 198399                Zubaan          India      Mozez Singh
# 198400                Zubaan          India      Mozez Singh
# 198401                Zubaan          India      Mozez Singh
# 198402                Zubaan          India      Mozez Singh
# 198403                Zubaan          India      Mozez Singh
#
#                        cast_x                 genre_x     type date_added  \
# 0                         NaN           Documentaries    Movie 2021-09-25
# 1                  Ama Qamata  International TV Shows  TV Show 2021-09-24
# 2                  Ama Qamata               TV Dramas  TV Show 2021-09-24
# 3                  Ama Qamata            TV Mysteries  TV Show 2021-09-24
# 4                 Khosi Ngema  International TV Shows  TV Show 2021-09-24
# ...                       ...                     ...      ...        ...
# 198399         Anita Shabdish    International Movies    Movie 2019-03-02
# 198400         Anita Shabdish        Music & Musicals    Movie 2019-03-02
# 198401  Chittaranjan Tripathy                  Dramas    Movie 2019-03-02
# 198402  Chittaranjan Tripathy    International Movies    Movie 2019-03-02
# 198403  Chittaranjan Tripathy        Music & Musicals    Movie 2019-03-02
#
#         release_year  rating  duration  \
# 0               2020   teens        90
# 1               2021  adults         2
# 2               2021  adults         2
# 3               2021  adults         2
# 4               2021  adults         2
# ...              ...     ...       ...
# 198399          2015   teens       111
# 198400          2015   teens       111
# 198401          2015   teens       111
# 198402          2015   teens       111
# 198403          2015   teens       111
#
#                                               description  day  month  year  \
# 0       As her father nears the end of his life, filmm...   25      9  2021
# 1       After crossing paths at a party, a Cape Town t...   24      9  2021
# 2       After crossing paths at a party, a Cape Town t...   24      9  2021
# 3       After crossing paths at a party, a Cape Town t...   24      9  2021
# 4       After crossing paths at a party, a Cape Town t...   24      9  2021
# ...                                                   ...  ...    ...   ...
# 198399  A scrappy but poor boy worms his way into a ty...    2      3  2019
# 198400  A scrappy but poor boy worms his way into a ty...    2      3  2019
# 198401  A scrappy but poor boy worms his way into a ty...    2      3  2019
# 198402  A scrappy but poor boy worms his way into a ty...    2      3  2019
# 198403  A scrappy but poor boy worms his way into a ty...    2      3  2019
#
#        month_name   weekday
# 0       September  Saturday
# 1       September    Friday
# 2       September    Friday
# 3       September    Friday
# 4       September    Friday
# ...           ...       ...
# 198399      March  Saturday
# 198400      March  Saturday
# 198401      March  Saturday
# 198402      March  Saturday
# 198403      March  Saturday
#
# [198404 rows x 16 columns]

# %%
df_new.rename(columns={'country_x':'country','director_x':'director','cast_x':'cast',"genre_x":"genre"},inplace=True)
df_new
# Out:
#                        title        country         director  \
# 0       Dick Johnson Is Dead  United States  Kirsten Johnson
# 1              Blood & Water   South Africa              NaN
# 2              Blood & Water   South Africa              NaN
# 3              Blood & Water   South Africa              NaN
# 4              Blood & Water   South Africa              NaN
# ...                      ...            ...              ...
# 198399                Zubaan          India      Mozez Singh
# 198400                Zubaan          India      Mozez Singh
# 198401                Zubaan          India      Mozez Singh
# 198402                Zubaan          India      Mozez Singh
# 198403                Zubaan          India      Mozez Singh
#
#                          cast                   genre     type date_added  \
# 0                         NaN           Documentaries    Movie 2021-09-25
# 1                  Ama Qamata  International TV Shows  TV Show 2021-09-24
# 2                  Ama Qamata               TV Dramas  TV Show 2021-09-24
# 3                  Ama Qamata            TV Mysteries  TV Show 2021-09-24
# 4                 Khosi Ngema  International TV Shows  TV Show 2021-09-24
# ...                       ...                     ...      ...        ...
# 198399         Anita Shabdish    International Movies    Movie 2019-03-02
# 198400         Anita Shabdish        Music & Musicals    Movie 2019-03-02
# 198401  Chittaranjan Tripathy                  Dramas    Movie 2019-03-02
# 198402  Chittaranjan Tripathy    International Movies    Movie 2019-03-02
# 198403  Chittaranjan Tripathy        Music & Musicals    Movie 2019-03-02
#
#         release_year  rating  duration  \
# 0               2020   teens        90
# 1               2021  adults         2
# 2               2021  adults         2
# 3               2021  adults         2
# 4               2021  adults         2
# ...              ...     ...       ...
# 198399          2015   teens       111
# 198400          2015   teens       111
# 198401          2015   teens       111
# 198402          2015   teens       111
# 198403          2015   teens       111
#
#                                               description  day  month  year  \
# 0       As her father nears the end of his life, filmm...   25      9  2021
# 1       After crossing paths at a party, a Cape Town t...   24      9  2021
# 2       After crossing paths at a party, a Cape Town t...   24      9  2021
# 3       After crossing paths at a party, a Cape Town t...   24      9  2021
# 4       After crossing paths at a party, a Cape Town t...   24      9  2021
# ...                                                   ...  ...    ...   ...
# 198399  A scrappy but poor boy worms his way into a ty...    2      3  2019
# 198400  A scrappy but poor boy worms his way into a ty...    2      3  2019
# 198401  A scrappy but poor boy worms his way into a ty...    2      3  2019
# 198402  A scrappy but poor boy worms his way into a ty...    2      3  2019
# 198403  A scrappy but poor boy worms his way into a ty...    2      3  2019
#
#        month_name   weekday
# 0       September  Saturday
# 1       September    Friday
# 2       September    Friday
# 3       September    Friday
# 4       September    Friday
# ...           ...       ...
# 198399      March  Saturday
# 198400      March  Saturday
# 198401      March  Saturday
# 198402      March  Saturday
# 198403      March  Saturday
#
# [198404 rows x 16 columns]

# %%
df_new.head()
# Out:
#                   title        country         director         cast  \
# 0  Dick Johnson Is Dead  United States  Kirsten Johnson          NaN
# 1         Blood & Water   South Africa              NaN   Ama Qamata
# 2         Blood & Water   South Africa              NaN   Ama Qamata
# 3         Blood & Water   South Africa              NaN   Ama Qamata
# 4         Blood & Water   South Africa              NaN  Khosi Ngema
#
#                     genre     type date_added  release_year  rating  duration  \
# 0           Documentaries    Movie 2021-09-25          2020   teens        90
# 1  International TV Shows  TV Show 2021-09-24          2021  adults         2
# 2               TV Dramas  TV Show 2021-09-24          2021  adults         2
# 3            TV Mysteries  TV Show 2021-09-24          2021  adults         2
# 4  International TV Shows  TV Show 2021-09-24          2021  adults         2
#
#                                          description  day  month  year  \
# 0  As her father nears the end of his life, filmm...   25      9  2021
# 1  After crossing paths at a party, a Cape Town t...   24      9  2021
# 2  After crossing paths at a party, a Cape Town t...   24      9  2021
# 3  After crossing paths at a party, a Cape Town t...   24      9  2021
# 4  After crossing paths at a party, a Cape Town t...   24      9  2021
#
#   month_name   weekday
# 0  September  Saturday
# 1  September    Friday
# 2  September    Friday
# 3  September    Friday
# 4  September    Friday

# %%
df_new.shape
# Out:
# (198404, 16)

# %%
df_new['cast']=df_new['cast'].replace(np.nan,'unknown')
df_new['director']=df_new['director'].replace(np.nan,'unknown')
df_new['country']=df_new['country'].replace(np.nan,'unknown')
df_new.isna().sum()
# Out:
# title           0
# country         0
# director        0
# cast            0
# genre           0
# type            0
# date_added      0
# release_year    0
# rating          0
# duration        0
# description     0
# day             0
# month           0
# year            0
# month_name      0
# weekday         0
# dtype: int64

# %%
df_new.drop(["description"],axis=1,inplace=True)
df_new
# Out:
#                        title        country         director  \
# 0       Dick Johnson Is Dead  United States  Kirsten Johnson
# 1              Blood & Water   South Africa          unknown
# 2              Blood & Water   South Africa          unknown
# 3              Blood & Water   South Africa          unknown
# 4              Blood & Water   South Africa          unknown
# ...                      ...            ...              ...
# 198399                Zubaan          India      Mozez Singh
# 198400                Zubaan          India      Mozez Singh
# 198401                Zubaan          India      Mozez Singh
# 198402                Zubaan          India      Mozez Singh
# 198403                Zubaan          India      Mozez Singh
#
#                          cast                   genre     type date_added  \
# 0                     unknown           Documentaries    Movie 2021-09-25
# 1                  Ama Qamata  International TV Shows  TV Show 2021-09-24
# 2                  Ama Qamata               TV Dramas  TV Show 2021-09-24
# 3                  Ama Qamata            TV Mysteries  TV Show 2021-09-24
# 4                 Khosi Ngema  International TV Shows  TV Show 2021-09-24
# ...                       ...                     ...      ...        ...
# 198399         Anita Shabdish    International Movies    Movie 2019-03-02
# 198400         Anita Shabdish        Music & Musicals    Movie 2019-03-02
# 198401  Chittaranjan Tripathy                  Dramas    Movie 2019-03-02
# 198402  Chittaranjan Tripathy    International Movies    Movie 2019-03-02
# 198403  Chittaranjan Tripathy        Music & Musicals    Movie 2019-03-02
#
#         release_year  rating  duration  day  month  year month_name   weekday
# 0               2020   teens        90   25      9  2021  September  Saturday
# 1               2021  adults         2   24      9  2021  September    Friday
# 2               2021  adults         2   24      9  2021  September    Friday
# 3               2021  adults         2   24      9  2021  September    Friday
# 4               2021  adults         2   24      9  2021  September    Friday
# ...              ...     ...       ...  ...    ...   ...        ...       ...
# 198399          2015   teens       111    2      3  2019      March  Saturday
# 198400          2015   teens       111    2      3  2019      March  Saturday
# 198401          2015   teens       111    2      3  2019      March  Saturday
# 198402          2015   teens       111    2      3  2019      March  Saturday
# 198403          2015   teens       111    2      3  2019      March  Saturday
#
# [198404 rows x 15 columns]

# %%
df_new.duplicated().sum()
# Out:
# np.int64(55)

# %%
df_movies=df_new[df_new['type']=='Movie']
df_tvs=df_new[df_new['type']=='TV Show']

# %%
df_movies.shape
# Out:
# (144295, 15)

# %%
df_tvs.shape
# Out:
# (54109, 15)

# %% [markdown]
# **Here we are replacing the column duration with a better name season for tv shows only in df_tvs**

# %%
df_tvs.rename(columns={'duration':'seasons'},inplace=True)
# Out:
# /var/folders/ms/5qd06gb52fb11qfl6dns7nwc0000gn/T/ipykernel_58897/243137724.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tvs.rename(columns={'duration':'seasons'},inplace=True)

# %%
plt.pie(df['type'].value_counts(),labels=df['type'].value_counts().index,autopct='%1.2f%%',
        explode=[0.03,0.04],shadow=True)
plt.suptitle('Movies vs TV Shows distribution')
plt.legend()
plt.show()

# %% [markdown]
# # **Let us start visulization**

# %%
df_temp=df_new.drop_duplicates(subset=['country','title'])
df_temp
# Out:
#                        title        country         director             cast  \
# 0       Dick Johnson Is Dead  United States  Kirsten Johnson          unknown
# 1              Blood & Water   South Africa          unknown       Ama Qamata
# 58                 Ganglands        unknown  Julien Leclercq    Sami Bouajila
# 85              Kota Factory          India          unknown       Mayur More
# 109            Midnight Mass        unknown    Mike Flanagan      Kate Siegel
# ...                      ...            ...              ...              ...
# 198300               Zinzana         Jordan  Majid Al Ansari      Ali Suliman
# 198318                Zodiac  United States    David Fincher     Mark Ruffalo
# 198348            Zombieland  United States  Ruben Fleischer  Jesse Eisenberg
# 198362                  Zoom  United States     Peter Hewitt        Tim Allen
# 198380                Zubaan          India      Mozez Singh    Vicky Kaushal
#
#                            genre     type date_added  release_year  rating  \
# 0                  Documentaries    Movie 2021-09-25          2020   teens
# 1         International TV Shows  TV Show 2021-09-24          2021  adults
# 58                Crime TV Shows  TV Show 2021-09-24          2021  adults
# 85        International TV Shows  TV Show 2021-09-24          2021  adults
# 109                    TV Dramas  TV Show 2021-09-24          2021  adults
# ...                          ...      ...        ...           ...     ...
# 198300                    Dramas    Movie 2016-03-09          2015  adults
# 198318               Cult Movies    Movie 2019-11-20          2007  adults
# 198348                  Comedies    Movie 2019-11-01          2009  adults
# 198362  Children & Family Movies    Movie 2020-01-11          2006    kids
# 198380                    Dramas    Movie 2019-03-02          2015   teens
#
#         duration  day  month  year month_name    weekday
# 0             90   25      9  2021  September   Saturday
# 1              2   24      9  2021  September     Friday
# 58             1   24      9  2021  September     Friday
# 85             2   24      9  2021  September     Friday
# 109            1   24      9  2021  September     Friday
# ...          ...  ...    ...   ...        ...        ...
# 198300        96    9      3  2016      March  Wednesday
# 198318       158   20     11  2019   November  Wednesday
# 198348        88    1     11  2019   November     Friday
# 198362        88   11      1  2020    January   Saturday
# 198380       111    2      3  2019      March   Saturday
#
# [10519 rows x 15 columns]

# %%
x=df_temp['country'].value_counts().head(10)
x
# Out:
# country
# United States     3596
# India             1038
# United Kingdom     772
# unknown            730
# Canada             427
# France             383
# Japan              313
# Spain              228
# Germany            223
# South Korea        222
# Name: count, dtype: int64

# %%
plt.figure(figsize=(17,8))
plt.title('Content across Countries')
label=sns.countplot(data=df_temp,x='country',hue='type',order=x.index)
for i in label.containers:
    label.bar_label(i)
plt.show()

# %%
df_movies_temp=df_movies.drop_duplicates(subset=['director','title'])
df_tvs_temp=df_tvs.drop_duplicates(subset=['director','title'])

plt.figure(figsize=(17,7))
plt.suptitle('Top 10 Directors')
plt.subplot(1,2,1)
x=df_movies_temp['director'].value_counts()[1:11]
label=sns.countplot(data=df_movies_temp,x='director',order=x.index,palette='plasma')
for i in label.containers:
    label.bar_label(i)
plt.title('Movies')
plt.xticks(rotation=45)
plt.xlabel('Director')
plt.ylabel('Movie Count')

plt.subplot(1,2,2)
y=df_tvs_temp['director'].value_counts()[1:11]
label=sns.countplot(data=df_tvs_temp,x='director',order=y.index,palette='husl')
for i in label.containers:
    label.bar_label(i)
plt.title('TV Shows')
plt.xticks(rotation=45)
plt.xlabel('Director')
plt.ylabel('TV Show Count')
plt.show()
# Out:
# /var/folders/ms/5qd06gb52fb11qfl6dns7nwc0000gn/T/ipykernel_58897/1083132654.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   label=sns.countplot(data=df_movies_temp,x='director',order=x.index,palette='plasma')
# /var/folders/ms/5qd06gb52fb11qfl6dns7nwc0000gn/T/ipykernel_58897/1083132654.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   label=sns.countplot(data=df_tvs_temp,x='director',order=y.index,palette='husl')

# %%
df_movies_temp=df_movies.drop_duplicates(subset=['genre','title'])
df_tvs_temp=df_tvs.drop_duplicates(subset=['genre','title'])

plt.figure(figsize=(17,7))
plt.suptitle('Top 10 Genres')
plt.subplot(1,2,1)
x=df_movies_temp['genre'].value_counts()[1:11]
label=sns.countplot(data=df_movies_temp,x='genre',order=x.index,palette='plasma')
for i in label.containers:
    label.bar_label(i)
plt.title('Movies')
plt.xticks(rotation=45)
plt.xlabel('Genres')
plt.ylabel('Movie Count')

plt.subplot(1,2,2)
y=df_tvs_temp['genre'].value_counts()[1:11]
label=sns.countplot(data=df_tvs_temp,x='genre',order=y.index,palette='viridis')
for i in label.containers:
    label.bar_label(i)
plt.title('TV Shows')
plt.xticks(rotation=45)
plt.xlabel('Genres')
plt.ylabel('TV Show Count')
plt.show()
# Out:
# /var/folders/ms/5qd06gb52fb11qfl6dns7nwc0000gn/T/ipykernel_58897/270467378.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   label=sns.countplot(data=df_movies_temp,x='genre',order=x.index,palette='plasma')
# /var/folders/ms/5qd06gb52fb11qfl6dns7nwc0000gn/T/ipykernel_58897/270467378.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   label=sns.countplot(data=df_tvs_temp,x='genre',order=y.index,palette='viridis')

# %%
df_movies_temp=df_movies.drop_duplicates(subset=['rating','title'])
df_tvs_temp=df_tvs.drop_duplicates(subset=['rating','title'])

plt.figure(figsize=(12,6))
plt.suptitle('Classification of content on Netflix')
plt.subplot(1,2,1)
plt.pie(df_movies_temp['rating'].value_counts(),labels=df_movies_temp['rating'].value_counts().index,autopct='%0.0f%%',
        explode=[0.05,0.03,0.03],shadow=True)
plt.title('Movies')
plt.legend()

plt.subplot(1,2,2)
plt.pie(df_tvs_temp['rating'].value_counts(),labels=df_tvs_temp['rating'].value_counts().index,autopct='%0.0f%%',
        explode=[0.05,0.03,0.03],shadow=True)
plt.title('TV Shows')
plt.legend()
plt.show()

# %%
df_movies_temp=df_movies.drop_duplicates(subset=['year','title'])
df_movies_temp
# Out:
#                                    title               country  \
# 0                   Dick Johnson Is Dead         United States
# 157     My Little Pony: A New Generation               unknown
# 177                              Sankofa         United States
# 329                         The Starling         United States
# 426                         Je Suis Karl               Germany
# ...                                  ...                   ...
# 198282                           Zinzana  United Arab Emirates
# 198318                            Zodiac         United States
# 198348                        Zombieland         United States
# 198362                              Zoom         United States
# 198380                            Zubaan                 India
#
#                    director              cast                     genre  \
# 0           Kirsten Johnson           unknown             Documentaries
# 157           Robert Cullen   Vanessa Hudgens  Children & Family Movies
# 177            Haile Gerima      Kofi Ghanaba                    Dramas
# 329          Theodore Melfi  Melissa McCarthy                  Comedies
# 426     Christian Schwochow       Luna Wedler                    Dramas
# ...                     ...               ...                       ...
# 198282      Majid Al Ansari       Ali Suliman                    Dramas
# 198318        David Fincher      Mark Ruffalo               Cult Movies
# 198348      Ruben Fleischer   Jesse Eisenberg                  Comedies
# 198362         Peter Hewitt         Tim Allen  Children & Family Movies
# 198380          Mozez Singh     Vicky Kaushal                    Dramas
#
#          type date_added  release_year  rating  duration  day  month  year  \
# 0       Movie 2021-09-25          2020   teens        90   25      9  2021
# 157     Movie 2021-09-24          2021    kids        91   24      9  2021
# 177     Movie 2021-09-24          1993  adults       125   24      9  2021
# 329     Movie 2021-09-24          2021   teens       104   24      9  2021
# 426     Movie 2021-09-23          2021  adults       127   23      9  2021
# ...       ...        ...           ...     ...       ...  ...    ...   ...
# 198282  Movie 2016-03-09          2015  adults        96    9      3  2016
# 198318  Movie 2019-11-20          2007  adults       158   20     11  2019
# 198348  Movie 2019-11-01          2009  adults        88    1     11  2019
# 198362  Movie 2020-01-11          2006    kids        88   11      1  2020
# 198380  Movie 2019-03-02          2015   teens       111    2      3  2019
#
#        month_name    weekday
# 0       September   Saturday
# 157     September     Friday
# 177     September     Friday
# 329     September     Friday
# 426     September   Thursday
# ...           ...        ...
# 198282      March  Wednesday
# 198318   November  Wednesday
# 198348   November     Friday
# 198362    January   Saturday
# 198380      March   Saturday
#
# [6031 rows x 15 columns]

# %%
mv_year=df_movies_temp['year'].value_counts()
mv_year.sort_index(inplace=True)
mv_year
# Out:
# year
# 2008       1
# 2009       2
# 2011      13
# 2012       3
# 2013       3
# 2014      19
# 2015      51
# 2016     224
# 2017     813
# 2018    1223
# 2019    1412
# 2020    1281
# 2021     986
# Name: count, dtype: int64

# %%
month_order=['January','February','March','April','May','June','July','August','September','October','November','December']
mv_month=df_movies_temp['month_name'].value_counts().loc[month_order]
mv_month
# Out:
# month_name
# January      535
# February     375
# March        518
# April        542
# May          433
# June         485
# July         559
# August       515
# September    510
# October      535
# November     489
# December     535
# Name: count, dtype: int64

# %%
day_order=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
mv_weekday=df_movies_temp['weekday'].value_counts().loc[day_order]
mv_weekday
# Out:
# weekday
# Monday        612
# Tuesday       842
# Wednesday     895
# Thursday     1040
# Friday       1537
# Saturday      543
# Sunday        562
# Name: count, dtype: int64

# %%
plt.figure(figsize=(17,8))
plt.suptitle('Movies added on Netflix')

plt.subplot(1,3,1)
label=sns.countplot(data=df_movies_temp,x='year',order=mv_year.index,palette='husl')
for i in label.containers:
    label.bar_label(i)
plt.xticks(rotation=45)
plt.xlabel('Year')
plt.title('Year wise distribution')

plt.subplot(1,3,2)
label=sns.countplot(data=df_movies_temp,x='month_name',order=mv_month.index,palette='plasma')
for i in label.containers:
    label.bar_label(i)
plt.xticks(rotation=45)
plt.xlabel('Month')
plt.title('Month wise distribution')

plt.subplot(1,3,3)
label=sns.countplot(data=df_movies_temp,x='weekday',order=mv_weekday.index,palette='viridis')
for i in label.containers:
    label.bar_label(i)
plt.xticks(rotation=45)
plt.xlabel('Day')
plt.title('Day wise distribution')
plt.show()
# Out:
# /var/folders/ms/5qd06gb52fb11qfl6dns7nwc0000gn/T/ipykernel_58897/377859066.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   label=sns.countplot(data=df_movies_temp,x='year',order=mv_year.index,palette='husl')
# /var/folders/ms/5qd06gb52fb11qfl6dns7nwc0000gn/T/ipykernel_58897/377859066.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   label=sns.countplot(data=df_movies_temp,x='month_name',order=mv_month.index,palette='plasma')
# /var/folders/ms/5qd06gb52fb11qfl6dns7nwc0000gn/T/ipykernel_58897/377859066.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   label=sns.countplot(data=df_movies_temp,x='weekday',order=mv_weekday.index,palette='viridis')

# %%
df_tvs_temp=df_tvs.drop_duplicates(subset=['year','title'])

tv_year=df_tvs_temp['year'].value_counts()
tv_year.sort_index(inplace=True)

month_order=['January','February','March','April','May','June','July','August','September','October','November','December']
tv_month=df_tvs_temp['month_name'].value_counts().loc[month_order]

day_order=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
tv_weekday=df_movies_temp['weekday'].value_counts().loc[day_order]

plt.figure(figsize=(17,8))
plt.suptitle('TV shows added on Netflix')

plt.subplot(1,3,1)
label=sns.countplot(data=df_tvs_temp,x='year',order=tv_year.index,palette='husl')
for i in label.containers:
    label.bar_label(i)
plt.xticks(rotation=45)
plt.xlabel('Year')
plt.title('Year wise distribution')

plt.subplot(1,3,2)
label=sns.countplot(data=df_tvs_temp,x='month_name',order=tv_month.index,palette='plasma')
for i in label.containers:
    label.bar_label(i)
plt.xticks(rotation=45)
plt.xlabel('Month')
plt.title('Month wise distribution')

plt.subplot(1,3,3)
label=sns.countplot(data=df_tvs_temp,x='weekday',order=tv_weekday.index,palette='viridis')
for i in label.containers:
    label.bar_label(i)
plt.xticks(rotation=45)
plt.xlabel('Day')
plt.title('Day wise distribution')
plt.show()
# Out:
# /var/folders/ms/5qd06gb52fb11qfl6dns7nwc0000gn/T/ipykernel_58897/1597255229.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   label=sns.countplot(data=df_tvs_temp,x='year',order=tv_year.index,palette='husl')
# /var/folders/ms/5qd06gb52fb11qfl6dns7nwc0000gn/T/ipykernel_58897/1597255229.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   label=sns.countplot(data=df_tvs_temp,x='month_name',order=tv_month.index,palette='plasma')
# /var/folders/ms/5qd06gb52fb11qfl6dns7nwc0000gn/T/ipykernel_58897/1597255229.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   label=sns.countplot(data=df_tvs_temp,x='weekday',order=tv_weekday.index,palette='viridis')

# %%
df_movies_temp=df_movies.drop_duplicates(subset=['duration','title'])
df_tvs_temp=df_tvs.drop_duplicates(subset=['seasons','title'])

plt.figure(figsize=(17,8))
plt.suptitle('Average duration and season of Content duration on Netflix')

plt.subplot(1,2,1)
label=sns.histplot(df_movies_temp['duration'],bins=10,color='red',kde=True)
for i in label.containers:
    label.bar_label(i)
plt.xlabel('Duration')
plt.title('Movies')

plt.subplot(1,2,2)
label=sns.histplot(data=df_tvs_temp,x='seasons',bins=10,color='g',kde=True)
for i in label.containers:
    label.bar_label(i)
plt.xlabel('Seasons')
plt.title('TV Shows')
plt.show()

# %%
plt.figure(figsize=(17,8))
plt.suptitle('Average duration and season of Content duration on Netflix')

plt.subplot(1,2,1)
sns.boxplot(y=df_movies_temp['duration'])
plt.title('Movies')

plt.subplot(1,2,2)
sns.boxplot(y=df_tvs_temp['seasons'])
plt.title('TV Shows')
plt.show()

# %%
def remove_outliers(df_col):
    Q1 = df_col.quantile(0.25)
    Q3 = df_col.quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    return df_col[(df_col >= lower) & (df_col <= upper)]

movies_duration_clean = remove_outliers(df_movies_temp['duration'])
tv_seasons_clean = remove_outliers(df_tvs_temp['seasons'])

plt.figure(figsize=(17,8))
plt.suptitle('Movie Durations and TV Show Seasons (Outliers Removed)')

plt.subplot(1,2,1)
sns.boxplot(y=movies_duration_clean)
plt.title('Movies')

plt.subplot(1,2,2)
sns.boxplot(y=tv_seasons_clean)
plt.title('TV Shows')

plt.show()

# %%
df_movies_temp=df_movies.drop_duplicates(subset=['cast','title'])
df_tvs_temp=df_tvs.drop_duplicates(subset=['cast','title'])

plt.figure(figsize=(17,7))
plt.suptitle('Top 10 Actors')
plt.subplot(1,2,1)
x=df_movies_temp['cast'].value_counts()[1:11]
label=sns.countplot(data=df_movies_temp,x='cast',order=x.index,palette='plasma')
for i in label.containers:
    label.bar_label(i)
plt.title('Movies')
plt.xticks(rotation=45)
plt.xlabel('Actors')
plt.ylabel('Movie Count')

plt.subplot(1,2,2)
y=df_tvs_temp['cast'].value_counts()[1:11]
label=sns.countplot(data=df_tvs_temp,x='cast',order=y.index,palette='viridis')
for i in label.containers:
    label.bar_label(i)
plt.title('TV Shows')
plt.xticks(rotation=45)
plt.xlabel('Actors')
plt.ylabel('TV Show Count')
plt.show()
# Out:
# /var/folders/ms/5qd06gb52fb11qfl6dns7nwc0000gn/T/ipykernel_58897/870838510.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   label=sns.countplot(data=df_movies_temp,x='cast',order=x.index,palette='plasma')
# /var/folders/ms/5qd06gb52fb11qfl6dns7nwc0000gn/T/ipykernel_58897/870838510.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   label=sns.countplot(data=df_tvs_temp,x='cast',order=y.index,palette='viridis')

# %%
pip install ydata-profiling
# Out:
# Requirement already satisfied: ydata-profiling in /opt/anaconda3/lib/python3.13/site-packages (4.18.4)
# Requirement already satisfied: scipy<1.17,>=1.8 in /opt/anaconda3/lib/python3.13/site-packages (from ydata-profiling) (1.16.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in /opt/anaconda3/lib/python3.13/site-packages (from ydata-profiling) (2.3.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in /opt/anaconda3/lib/python3.13/site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from ydata-profiling) (2.12.4)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in /opt/anaconda3/lib/python3.13/site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in /opt/anaconda3/lib/python3.13/site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in /opt/anaconda3/lib/python3.13/site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in /opt/anaconda3/lib/python3.13/site-packages (from ydata-profiling) (2.3.5)
# Requirement already satisfied: minify-html>=0.15.0 in /opt/anaconda3/lib/python3.13/site-packages (from ydata-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from ydata-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in /opt/anaconda3/lib/python3.13/site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in /opt/anaconda3/lib/python3.13/site-packages (from ydata-profiling) (2.32.5)
# Requirement already satisfied: tqdm<5,>=4.66.3 in /opt/anaconda3/lib/python3.13/site-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /opt/anaconda3/lib/python3.13/site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /opt/anaconda3/lib/python3.13/site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /opt/anaconda3/lib/python3.13/site-packages (from ydata-profiling) (0.14.5)
# Requirement already satisfied: typeguard<5,>=4 in /opt/anaconda3/lib/python3.13/site-packages (from ydata-profiling) (4.5.2)
# Requirement already satisfied: imagehash==4.3.2 in /opt/anaconda3/lib/python3.13/site-packages (from ydata-profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in /opt/anaconda3/lib/python3.13/site-packages (from ydata-profiling) (1.9.6)
# Requirement already satisfied: dacite<2,>=1.9 in /opt/anaconda3/lib/python3.13/site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in /opt/anaconda3/lib/python3.13/site-packages (from ydata-profiling) (0.62.1)
# Requirement already satisfied: PyWavelets in /opt/anaconda3/lib/python3.13/site-packages (from imagehash==4.3.2->ydata-profiling) (1.9.0)
# Requirement already satisfied: pillow in /opt/anaconda3/lib/python3.13/site-packages (from imagehash==4.3.2->ydata-profiling) (12.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in /opt/anaconda3/lib/python3.13/site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.45.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in /opt/anaconda3/lib/python3.13/site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.5.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=2->ydata-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=2->ydata-profiling) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=2->ydata-profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=2->ydata-profiling) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.32.0->ydata-profiling) (2026.6.17)
# Requirement already satisfied: patsy>=0.5.6 in /opt/anaconda3/lib/python3.13/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.1)
# Requirement already satisfied: attrs>=19.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (25.4.0)
# Requirement already satisfied: networkx>=2.4 in /opt/anaconda3/lib/python3.13/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.5)
# Requirement already satisfied: puremagic in /opt/anaconda3/lib/python3.13/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (2.2.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ydata_profiling import ProfileReport
prof=ProfileReport(df)
prof.to_file(output_file="output.html")
# Out:
# /var/folders/ms/5qd06gb52fb11qfl6dns7nwc0000gn/T/ipykernel_58897/135780652.py:1: DeprecationWarning:
#     `import ydata_profiling` is deprecated and will not receive more updates.
#     Please install fg-data-profiling via `pip install fg-data-profiling` and use `import data_profiling` instead.
#
#   from ydata_profiling import ProfileReport
# /opt/anaconda3/lib/python3.13/site-packages/ydata_profiling/utils/dataframe.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"index": "df_index"}, inplace=True)
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|                                                    | 0/16 [00:00<?, ?it/s]
#  12%|█████▌                                      | 2/16 [00:00<00:01, 12.82it/s]
# 100%|███████████████████████████████████████████| 16/16 [00:00<00:00, 59.36it/s]
# /opt/anaconda3/lib/python3.13/site-packages/ydata_profiling/model/pandas/discretize_pandas.py:52: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[7 7 7 ... 0 3 0]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   discretized_df.loc[:, column] = self._discretize_column(
# /opt/anaconda3/lib/python3.13/site-packages/ydata_profiling/model/pandas/discretize_pandas.py:52: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[7 7 7 ... 9 0 1]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   discretized_df.loc[:, column] = self._discretize_column(
# /opt/anaconda3/lib/python3.13/site-packages/ydata_profiling/model/pandas/discretize_pandas.py:52: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[9 9 9 ... 8 9 8]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   discretized_df.loc[:, column] = self._discretize_column(
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
plt.savefig('my_plot.png')

# %%
plt.savefig('my_plot.png')
